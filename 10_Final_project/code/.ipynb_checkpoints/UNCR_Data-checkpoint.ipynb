# %%
import pandas as pd
import numpy as np
df_apps = pd.read_csv('Assylum_applications_2014-2024.csv')
df_desc = pd.read_csv('Assylum_descisions_2014-2024.csv')
df_inDisplac = pd.read_csv('internal_displacment_2014-2024.csv')

# %%
df_apps.head(10)
# Out:
#    Year Country of origin         Country of asylum Authority  \
# 0  2014              Iraq                 Indonesia         U
# 1  2014           Nigeria  United States of America         G
# 2  2014       Palestinian                   Algeria         U
# 3  2014             China                    France         G
# 4  2014           Ukraine                     Chile         G
# 5  2014           Algeria                Luxembourg         G
# 6  2014       South Sudan                     Egypt         U
# 7  2014              Iraq                      Oman         U
# 8  2014          Pakistan                    France         G
# 9  2014       Palestinian                Mauritania         U
#
#   Application type Stage of procedure Cases / Persons  applied
# 0                N                 FI               P      368
# 1                N                 IN               C      331
# 2                N                 FI               P      228
# 3                N                 FI               P     2673
# 4                N                 FI               P        5
# 5                N                 FI               P       41
# 6                R                 RA               P       46
# 7                N                 FI               P      161
# 8                N                 FI               P     2136
# 9                N                 FA               P        6

# %%
df_total_applied = df_apps[['Country of origin','applied']].groupby('Country of origin').sum().sort_values(by='applied', ascending=False).head(20).reset_index()
df_total_applied
# Out:
#                      Country of origin  applied
# 0                     Syrian Arab Rep.  1986844
# 1   Venezuela (Bolivarian Republic of)  1970125
# 2                          Afghanistan  1762334
# 3                                 Iraq  1022841
# 4                              Ukraine   831536
# 5                                Sudan   687672
# 6               Dem. Rep. of the Congo   670686
# 7                             Colombia   625641
# 8                              Somalia   587597
# 9                            Nicaragua   558944
# 10                            Honduras   556361
# 11                            Pakistan   552424
# 12                             Eritrea   546475
# 13                             Nigeria   535274
# 14                                Cuba   520162
# 15                             Türkiye   499309
# 16                               Haiti   487142
# 17              Iran (Islamic Rep. of)   422640
# 18                         El Salvador   406227
# 19                          Bangladesh   405489

# %%
df_desc.head(10)
# Out:
#    Year                     Country of origin Country of asylum Authority  \
# 0  2017                           Afghanistan           Germany         G
# 1  2020                              Colombia             Spain         G
# 2  2015  Serbia and Kosovo: S/RES/1244 (1999)           Germany         G
# 3  2015                               Albania           Germany         G
# 4  2016                               Albania           Germany         G
# 5  2016  Serbia and Kosovo: S/RES/1244 (1999)           Germany         G
# 6  2016                           Afghanistan           Germany         G
# 7  2017                                  Iraq           Germany         G
# 8  2014                              Zimbabwe      South Africa         G
# 9  2021                              Colombia             Spain         G
#
#   Stage of procedure Cases / Persons  Recognized decisions  \
# 0                NaN               P                 17718
# 1                 FI               P                   624
# 2                NaN               P                    17
# 3                NaN               P                     5
# 4                NaN               P                    18
# 5                NaN               P                    13
# 6                NaN               P                 13647
# 7                NaN               P                 24009
# 8                 FI               P                    15
# 9                 FI               P                  1169
#
#    Complementary protection  Rejected decisions  Otherwise closed  \
# 0                     32647               56309              5918
# 1                       152               37907                 0
# 2                       124               37130              3981
# 3                        69               31086              4075
# 4                       139               29681              5400
# 5                       156               25836              4293
# 6                     24108               24734              4892
# 7                     15489               21751              7713
# 8                         0               20244                10
# 9                        53               18619                 0
#
#    Total decisions
# 0           112592
# 1            38683
# 2            41252
# 3            35235
# 4            35238
# 5            30298
# 6            67381
# 7            68962
# 8            20269
# 9            19841

# %%
df_desc.tail(10)
# Out:
#        Year                   Country of origin          Country of asylum  \
# 54792  2015                                Cuba                   Curacao
# 54793  2016  Venezuela (Bolivarian Republic of)                   Curacao
# 54794  2020  Venezuela (Bolivarian Republic of)                   Curacao
# 54795  2016                            Colombia                   Curacao
# 54796  2019                                Cuba                   Curacao
# 54797  2023  Venezuela (Bolivarian Republic of)  Sint Maarten (Dutch part)
# 54798  2016                    Syrian Arab Rep.  Sint Maarten (Dutch part)
# 54799  2023                            Colombia  Sint Maarten (Dutch part)
# 54800  2020                                Cuba  Sint Maarten (Dutch part)
# 54801  2024                            Colombia  Sint Maarten (Dutch part)
#
#       Authority Stage of procedure Cases / Persons  Recognized decisions  \
# 54792         U                 FI               P                     5
# 54793         U                 FI               P                     5
# 54794         U                 FI               P                    11
# 54795         U                 FI               P                     5
# 54796         U                 FI               P                     0
# 54797         U                 FI               P                     0
# 54798         U                 FI               P                     0
# 54799         U                 FI               P                     5
# 54800         U                 FI               P                     5
# 54801         U                 FI               P                     5
#
#        Complementary protection  Rejected decisions  Otherwise closed  \
# 54792                         0                   0                 0
# 54793                         0                   0                 0
# 54794                         0                   0                 0
# 54795                         0                   0                 5
# 54796                         0                   0                 5
# 54797                         0                   0                17
# 54798                         0                   0                 5
# 54799                         0                   0                 0
# 54800                         0                   0                 0
# 54801                         0                   0                 0
#
#        Total decisions
# 54792                5
# 54793                5
# 54794               11
# 54795               10
# 54796                5
# 54797               17
# 54798                5
# 54799                5
# 54800                5
# 54801                5

# %%
df_todal_decisions = df_desc[['Country of origin','Total decisions']].groupby('Country of origin').sum().sort_values(by='Total decisions', ascending=False).head(20).reset_index()

# %%
df_todal_decisions
# Out:
#                        Country of origin  Total decisions
# 0                       Syrian Arab Rep.          1995499
# 1                            Afghanistan          1657853
# 2                               Unknown           1325466
# 3                                   Iraq          1034544
# 4     Venezuela (Bolivarian Republic of)           833398
# 5                                Ukraine           798475
# 6                 Dem. Rep. of the Congo           632843
# 7                               Pakistan           558779
# 8                                Nigeria           556228
# 9                                Eritrea           458076
# 10                Iran (Islamic Rep. of)           432548
# 11                               Somalia           424456
# 12                            Bangladesh           373416
# 13                               Türkiye           371075
# 14  Serbia and Kosovo: S/RES/1244 (1999)           361905
# 15                               Albania           344286
# 16                              Ethiopia           326094
# 17                    Russian Federation           315491
# 18                              Honduras           304240
# 19                                 China           290961

# %%
df_inDisplac.head(10)
df_inDisplac[df_inDisplac['Year']==2014].sort_values(by='Total', ascending=False).head(20)
# Out:
#     Year       Country of origin Country of asylum    Total
# 46  2014        Syrian Arab Rep.                 -  7600000
# 12  2014                Colombia                 -  6044000
# 23  2014                    Iraq                 -  3276000
# 44  2014                   Sudan                 -  3100000
# 11  2014  Dem. Rep. of the Congo                 -  2757000
# 36  2014                Pakistan                 -  1900000
# 45  2014             South Sudan                 -  1498000
# 43  2014                 Somalia                 -  1107000
# 35  2014                 Nigeria                 -  1075000
# 51  2014                 Türkiye                 -   954000
# 21  2014                   India                 -   854000
# 0   2014             Afghanistan                 -   805000
# 53  2014                 Ukraine                 -   647000
# 32  2014                 Myanmar                 -   645000
# 3   2014              Azerbaijan                 -   569000
# 7   2014    Central African Rep.                 -   439000
# 5   2014              Bangladesh                 -   426000
# 26  2014                   Libya                 -   400000
# 15  2014                Ethiopia                 -   397000
# 55  2014                   Yemen                 -   334000

# %%
df_inDisplac.head(20).sort_values(by='Total', ascending=False)
df[(df['artists'] == "Taylor Swift") & (df['released_year'] > 2021)

# %%
df_inDisplac[df_inDisplac['Country of asylum'].isnull()]
values = df_inDisplac['Country of asylum'].any
print(values)
# Out:
# <bound method Series.any of 0      -
# 1      -
# 2      -
# 3      -
# 4      -
#       ..
# 640    -
# 641    -
# 642    -
# 643    -
# 644    -
# Name: Country of asylum, Length: 645, dtype: object>

# %%
df_inDisplac.drop('Country of asylum', axis=1, inplace=True)

# %%
df_inDisplac[df_inDisplac['Year'].isnull()]
df_inDisplac['Year'].any
df_inDisplac['Year'].value_counts()
# Out:
# Year
# 2023    65
# 2024    65
# 2022    64
# 2019    61
# 2021    60
# 2020    59
# 2014    57
# 2016    55
# 2018    55
# 2015    52
# 2017    52
# Name: count, dtype: int64

# %%
values_displaced = df_inDisplac[df_inDisplac['Year']==2022].tail(60)
unknown_value = df_inDisplac[df_inDisplac['Country of origin']=='-']
unknown_value
# Out:
#      Year Country of origin  Total
# 56   2014                 -  20000
# 108  2015                 -  82000
# 163  2016                 -  20000
# 215  2017                 -  31000
# 270  2018                 -  31000
# 331  2019                 -  31000
# 390  2020                 -  19000
# 450  2021                 -  15000
# 514  2022                 -  56000
# 579  2023                 -  42000
# 644  2024                 -  42000

# %%
pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-5.3.0-cp310-cp310-macosx_10_9_universal2.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 15.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Installing collected packages: lxml
# Successfully installed lxml-5.3.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
